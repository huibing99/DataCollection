# %%
begin, end = map(int,input().split())
for i in range(begin, end):
    print("twarc hydrate cut_id/tweeid%s.txt > tweets/tweets%s.jsonl"%(i, i))
# Out:
# 1 5
# twarc hydrate cut_id/tweeid1.txt > tweets/tweets1.jsonl
# twarc hydrate cut_id/tweeid2.txt > tweets/tweets2.jsonl
# twarc hydrate cut_id/tweeid3.txt > tweets/tweets3.jsonl
# twarc hydrate cut_id/tweeid4.txt > tweets/tweets4.jsonl

# %%
# 分国籍

nations = ["Argentina", "Australia", "Brazil", "Canada", "Colombia", "Denmark", "France", "India", "Indonesia", "Iran",
           "Ireland", "Italy", "Japan", "Kenya", "Malaysia", "New Zealand", "Nigeria", "Pakistan", "Philippines", "Russia", 
          "Singapore", "South Africa", "South Korea", "Spain", "Thailand", "Turkey", "United Kingdom", "United States","Vietnam"]

for i in nations:
    print("twarc hydrate \"D:\Vaccine Data\\tweeid\\tweeid_%s.txt\" > \"D:\Vaccine Data\\tweets\\tweets_%s.jsonl\""%(i, i))
# Out:
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_Argentina.txt" > "D:\Vaccine Data\tweets\tweets_Argentina.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_Australia.txt" > "D:\Vaccine Data\tweets\tweets_Australia.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_Brazil.txt" > "D:\Vaccine Data\tweets\tweets_Brazil.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_Canada.txt" > "D:\Vaccine Data\tweets\tweets_Canada.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_Colombia.txt" > "D:\Vaccine Data\tweets\tweets_Colombia.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_Denmark.txt" > "D:\Vaccine Data\tweets\tweets_Denmark.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_France.txt" > "D:\Vaccine Data\tweets\tweets_France.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_India.txt" > "D:\Vaccine Data\tweets\tweets_India.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_Indonesia.txt" > "D:\Vaccine Data\tweets\tweets_Indonesia.jsonl"
# ...

# %%
# 切割后

for i in range(404, 415):
    print("twarc hydrate \"E:\Vaccine Data\\tweeid\\tweeid_United States\\tweeid_United States_%d.txt\" > \"E:\Vaccine Data\\tweets\\tweets_United States\\tweets_United States_%d.jsonl\""%(i, i))
# Out:
# twarc hydrate "E:\Vaccine Data\tweeid\tweeid_United States\tweeid_United States_404.txt" > "E:\Vaccine Data\tweets\tweets_United States\tweets_United States_404.jsonl"
# twarc hydrate "E:\Vaccine Data\tweeid\tweeid_United States\tweeid_United States_405.txt" > "E:\Vaccine Data\tweets\tweets_United States\tweets_United States_405.jsonl"
# twarc hydrate "E:\Vaccine Data\tweeid\tweeid_United States\tweeid_United States_406.txt" > "E:\Vaccine Data\tweets\tweets_United States\tweets_United States_406.jsonl"
# twarc hydrate "E:\Vaccine Data\tweeid\tweeid_United States\tweeid_United States_407.txt" > "E:\Vaccine Data\tweets\tweets_United States\tweets_United States_407.jsonl"
# twarc hydrate "E:\Vaccine Data\tweeid\tweeid_United States\tweeid_United States_408.txt" > "E:\Vaccine Data\tweets\tweets_United States\tweets_United States_408.jsonl"
# ...

# %%
# 切割后  UK

for i in range(146):
    print("twarc hydrate \"D:\Vaccine Data\\tweeid\\tweeid_United Kingdom\\tweeid_United_Kingdom_%d.txt\" > \"D:\Vaccine Data\\tweets\\tweets_United Kingdom\\tweets_United_Kingdom_%d.jsonl\""%(i, i))
# Out:
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_United Kingdom\tweeid_United_Kingdom_0.txt" > "D:\Vaccine Data\tweets\tweets_United Kingdom\tweets_United_Kingdom_0.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_United Kingdom\tweeid_United_Kingdom_1.txt" > "D:\Vaccine Data\tweets\tweets_United Kingdom\tweets_United_Kingdom_1.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_United Kingdom\tweeid_United_Kingdom_2.txt" > "D:\Vaccine Data\tweets\tweets_United Kingdom\tweets_United_Kingdom_2.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_United Kingdom\tweeid_United_Kingdom_3.txt" > "D:\Vaccine Data\tweets\tweets_United Kingdom\tweets_United_Kingdom_3.jsonl"
# twarc hydrate "D:\Vaccine Data\tweeid\tweeid_United Kingdom\tweeid_United_Kingdom_4.txt" > "D:\Vaccine Data\tweets\tweets_United Kingdom\tweets_United_Kingdom_4.jsonl"
# ...
