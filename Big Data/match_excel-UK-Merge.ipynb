# %%
import jsonlines
import time
import csv
import codecs
import pandas as pd

# %%
# # 打开写入文件
# outfile = codecs.open('E:/Vaccine Data/MatchedData/data_United Kingdom.csv', 'a+', encoding = 'utf-8')
# csv_writer = csv.writer(outfile, lineterminator='\n')
data = pd.read_csv('E:/Vaccine Data/MatchedData/United Kingdom/data_United Kingdom_0.csv', sep='\t')
data.head()
# Out:
#               tweet_id                                          full_text  \
# 0  1222025479521275905  'New vaccines to target the #WuhanCoronavirus ...
# 1  1222066968968224770  '@Queenoftheunse1 This is MISINFORMATION. \nTh...
# 2  1222067698982707201  "@northrhein It's not man-made. This was a pat...
# 3  1222068250428825600  '@BuddhaRascal @O_Rich_ THIS IS A LIE \nA pate...
# 4  1222069880385626112  '@warriors_mom @cvpayne @Varneyco @seanhannity...
#
#   Keywords      tweet_timestamp  valence_intensity  fear_intensity  \
# 0  vaccin   2020-01-27 21-15-53              0.497           0.431
# 1  vaccin   2020-01-28 00-00-44              0.454           0.451
# 2  vaccin   2020-01-28 00-03-39              0.433           0.503
# 3  vaccin   2020-01-28 00-05-50              0.471           0.478
# 4  vaccin   2020-01-28 00-12-19              0.421           0.406
#
#    anger_intensity  happiness_intensity  sadness_intensity         sentiment  \
# ...

# %%
   
for i_ in range(146):
    # 读入数据
    data = pd.read_csv('E:/Vaccine Data/MatchedData/United Kingdom/data_United Kingdom_%s.csv'%i_, sep='\t')
    # 写出文件
    data.to_csv("E:/Vaccine Data/MatchedData/data_United Kingdom.csv", mode = "a+", index=False, header = None, sep='\t')

# %%
data = pd.read_csv("E:/Vaccine Data/MatchedData/data_United Kingdom.csv", header = None, sep='\t', 
                   names = ["tweet_id", "full_text", "keyword", "tweet_timestamp",  "valence_intensity", "fear_intensity", "anger_intensity", "happiness_intensity", "sadness_intensity", "sentiment", "emotion"])

# %%
data
# Out:
#                    tweet_id  \
# 0       1222025479521275905
# 1       1222066968968224770
# 2       1222067698982707201
# 3       1222068250428825600
# 4       1222069880385626112
# 5       1222070197772783618
# 6       1222071000013189125
# 7       1222127245948604416
# 8       1222149267936219141
# 9       1222151034786799616
# 10      1222161145362026496
# 11      1222161350782324736
# 12      1222162549338255361
# 13      1222164867211309056
# 14      1222183001989287937
# 15      1222185627980042242
# 16      1222187301566132225
# 17      1222190454130671616
# 18      1222200798370828288
# 19      1222201036175290368
# 20      1222208156975140867
# 21      1222241180836139009
# 22      1222254367463526405
# 23      1222259733530402818
# 24      1222268202199195648
# 25      1222269507068223492
# 26      1222278627280203777
# 27      1222279451754541056
# 28      1222294897044213762
# 29      1222298067707269123
# ...                     ...
# 999892  1433212259581505538
# ...

# %%
data.to_csv("E:/Vaccine Data/MatchedData/data_United Kingdom(all).csv", mode = "a+", index=False, sep='\t')

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3d8483998d6f> in <module>()
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable
